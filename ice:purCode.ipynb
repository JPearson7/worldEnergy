# %%
# %matplotlib inline

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import psycopg2
import seaborn as sbn
from altair import Chart, X, Y, Color, Scale
import altair as alt
from vega_datasets import data
import requests
from bs4 import BeautifulSoup
matplotlib.style.use('ggplot')
import io
import request

# %%
url=
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')))


url="https://raw.githubusercontent.com/JPearson7/worldEnergy/main/IcelandCostAnalysis.csv"
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')))

print(c)
# Out:
#                Unnamed: 0                                         Unnamed: 1  \
# 0           Efni/Subject:  Talnaefni Orkustofnunar / Orkustofnun Data Rep...
# 1           Titill/Title:  Efnahagslegur ávinningur af nýtingu jarðvarma ...
# 2       Lykilorð/Keyword:  Jarðvarmi, jarðhiti, hitaveita, húshitun olía,...
# 3    Auðkenni/Identifier:                                    OS-2019-T010-01
# 4       Útgáfudagur/Date:                                            10/8/19
# ..                    ...                                                ...
# 119                  2014                                              20.4
# 120                  2015                                              21.1
# 121                  2016                                              20.9
# 122                  2017                                              20.1
# 123                  2018                                              24.0
#
# ...

# %%
url="https://raw.githubusercontent.com/JPearson7/worldEnergy/main/Iceland%20Data%20RenEnergytransfer.csv"
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')))

print(c)
# Out:
#             Unnamed: 0                                         Unnamed: 1  \
# 0                  NaN                                                NaN
# 1        Efni/Subject:  Talnaefni Orkustofnunar / Orkustofnun Data Rep...
# 2        Titill/Title:  Frumorkunotkun á Íslandi 1940-2019/Primary Ene...
# 3    Lykilorð/Keyword:  Frumorka, vatnsafl, jarðhiti, olía, kol, mór, ...
# 4                  NaN  Primary energy, hydropower, geothermal, oil, c...
# ..                 ...                                                ...
# 234                NaN                                                NaN
# 235                NaN                                                NaN
# 236                NaN                                                NaN
# 237                NaN                                                NaN
# 238                NaN                                                NaN
#
#     Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# ...

# %%
url="https://raw.githubusercontent.com/JPearson7/worldEnergy/main/OS-2021-T008-01%20iceland%20energy%20dist.csv"
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')))
x=list(c)
print(x)
# Out:
# ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52']
